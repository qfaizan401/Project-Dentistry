# %%
import os
from skimage import io, measure, img_as_ubyte
import matplotlib.pyplot as plt
import numpy as np
from skimage.filters import threshold_multiotsu
from skimage.color import label2rgb
import pandas as pd

# %%
img_dir = 'catagorical_data/root_canal_treated4'
img_list = os.listdir(img_dir)
img_list.sort(key=len)
img_list
# Out:
# ['6.jpg',
#  '10.jpg',
#  '12.jpg',
#  '15.jpg',
#  '16.jpg',
#  '19.jpg',
#  '31.jpg',
#  '32.jpg',
#  '33.jpg',
#  '34.jpg',
#  '42.jpg',
#  '44.jpg',
#  '52.jpg',
#  '53.jpg',
#  '56.jpg',
#  '58.jpg',
#  '64.jpg',
#  '65.jpg',
#  '68.jpg',
#  '74.jpg',
#  '79.jpg',
#  '103.jpg',
#  '127.jpg',
#  '130.jpg',
#  '132.jpg',
#  '136.jpg',
#  '142.jpg',
#  '146.jpg',
#  '154.jpg',
#  '159.jpg',
#  '163.jpg',
#  '166.jpg',
#  '169.jpg',
#  '171.jpg',
#  '182.jpg',
#  '190.jpg',
#  '201.jpg',
#  '206.jpg',
#  '207.jpg',
#  '220.jpg',
#  '221.jpg',
#  '226.jpg',
#  '228.jpg',
#  '231.jpg',
#  '232.jpg',
#  '233.jpg',
#  '240.jpg',
#  '244.jpg',
#  '258.jpg',
#  '259.jpg',
#  '260.jpg',
#  '264.jpg',
#  '275.jpg',
#  '284.jpg',
#  '294.jpg',
#  '298.jpg',
#  '301.jpg',
#  '304.jpg',
#  '312.jpg',
#  '316.jpg',
#  '319.jpg',
#  '320.jpg',
#  '327.jpg',
#  '329.jpg',
#  '330.jpg',
#  '333.jpg',
#  '336.jpg',
#  '341.jpg',
#  '342.jpg',
#  '343.jpg',
#  '348.jpg',
#  '349.jpg',
#  '355.jpg',
#  '359.jpg',
#  '361.jpg',
#  '373.jpg',
#  '375.jpg',
#  '383.jpg',
#  '386.jpg',
#  '388.jpg',
#  '390.jpg',
#  '392.jpg',
#  '405.jpg',
#  '407.jpg',
#  '413.jpg',
#  '419.jpg',
#  '420.jpg',
#  '427.jpg',
#  '428.jpg',
#  '434.jpg',
#  '440.jpg',
#  '444.jpg',
#  '446.jpg',
#  '447.jpg',
#  '452.jpg',
#  '453.jpg',
#  '454.jpg',
#  '455.jpg',
#  '458.jpg',
#  '460.jpg',
#  '466.jpg',
#  '471.jpg',
#  '479.jpg',
#  '480.jpg',
#  '481.jpg',
#  '488.jpg',
#  '489.jpg',
#  '512.jpg',
#  '513.jpg',
#  '525.jpg',
#  '526.jpg',
#  '532.jpg',
#  '533.jpg',
#  '537.jpg',
#  '539.jpg',
#  '541.jpg',
#  '542.jpg',
#  '545.jpg',
#  '552.jpg',
#  '554.jpg',
#  '555.jpg',
#  '556.jpg',
#  '566.jpg',
#  '578.jpg',
#  '581.jpg',
#  '583.jpg',
#  '595.jpg',
#  '601.jpg',
#  '604.jpg',
#  '605.jpg',
#  '613.jpg',
#  '615.jpg',
#  '618.jpg',
#  '624.jpg',
#  '626.jpg',
#  '634.jpg',
#  '635.jpg',
#  '640.jpg',
#  '643.jpg',
#  '644.jpg',
#  '648.jpg',
#  '651.jpg',
#  '656.jpg',
#  '662.jpg',
#  '679.jpg',
#  '680.jpg',
#  '690.jpg',
#  '694.jpg',
#  '696.jpg',
#  '700.jpg',
#  '704.jpg']

# %%
imgs = [io.imread(os.path.join(img_dir, f), as_gray=True) for f in img_list]
thresholds_list = [threshold_multiotsu(thresholds) for thresholds in imgs]
regions = [img_as_ubyte(np.digitize(imgs[i], bins=thresholds_list[i])) for i in range(len(imgs))]
label_imgs = [measure.label(regions[i], connectivity=imgs[i].ndim) for i in range(len(regions))]
image_label_overlay = [label2rgb(label_imgs[i], image=imgs[i]) for i in range(len(imgs))]
properties = ['label', 'area', 'bbox', 'bbox_area', 'centroid', 
              'slice', 'inertia_tensor', 'solidity', 'mean_intensity']
#props_list = [measure.regionprops_table(label_imgs[i], imgs[i], properties=properties) for i in range(len(imgs))]
# Out:
# D:\Faizan\Anaconda3\envs\tensorflow\lib\site-packages\skimage\util\dtype.py:525: UserWarning: Downcasting int64 to uint8 without scaling because max value 2 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# <ipython-input-3-f459936fa692>:5: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
#   image_label_overlay = [label2rgb(label_imgs[i], image=imgs[i]) for i in range(len(imgs))]

# %%
csv_dir = 'catagorical_data/csv/root_canal_treated4'
for i in range(len(imgs)): 
    img_props = measure.regionprops_table(label_imgs[i], imgs[i], properties=properties) 
    temp_img = pd.DataFrame(img_props)
    temp_img = temp_img[temp_img['area']>50]
    temp_img.to_csv(os.path.join(csv_dir, f'temp_img{i}.csv'))
